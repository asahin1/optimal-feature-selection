# %%
import numpy as np

# %%
def corr2cov(p: np.ndarray, s: np.ndarray) -> np.ndarray:
    """Covariance matrix from correlation & standard deviations"""
    d = np.diag(s)
    return d @ p @ d

# %%
corr = np.array([[1., -0.4, 0.3],
                 [-0.4, 1., 0.3],
                 [0.3, 0.3, 1]])
stdev = np.array([6., 2, 1])
mean = np.array([2., 0.5, 1])
cov = corr2cov(corr, stdev)

# %%
data = np.random.multivariate_normal(mean=mean, cov=cov, size=500)

# %%
import matplotlib.pyplot as plt

plt.scatter(data[:,0],data[:,1])
plt.axis('equal')
plt.show()

# %%
plt.scatter(data[:,0],data[:,2])
plt.axis('equal')
plt.show()

# %%
plt.scatter(data[:,1],data[:,2])
plt.axis('equal')
plt.show()

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#           0         1
# 0  2.000232 -0.336088
# 1  3.365079  0.740418
# 2 -0.959039  2.113301
# 3  2.241233  1.946691
# 4  3.784385  0.557520

# %%
corr @ cov
# Out:
# array([[ 36.96,  -2.8 ],
#        [-16.8 ,   1.96]])
