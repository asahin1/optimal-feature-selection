# %% [markdown]
# # Data Generation

# %% [markdown]
# Generation of synthetic data for regression task

# %% [markdown]
# ## Data generation using scikit-learn's make_regression:

# %%
import numpy as np
from sklearn.datasets import make_regression

# %% [markdown]
# Parameters:

# %%
n_samples = 10000
n_features = 20
n_informative = 8
n_targets = 1
bias = 1
effective_rank = 20
tail_strength = 0.7
noise = 0.1
shuffle = True
coef = True
random_state = 42

# %%
X, y, coef= make_regression(n_samples, n_features, n_informative, n_targets, bias,
                      effective_rank, tail_strength, noise, shuffle, coef,
                      random_state)

# %%
print(coef)
# Out:
# [ 0.          0.         90.99230199 63.609166    0.          0.
#   0.         39.22466532 88.85581405 39.04300741 65.26862413  0.
#   0.          0.          0.          0.         63.07556531  0.
#  72.9658752   0.        ]

# %% [markdown]
# ### Quick Inspection of the Data

# %%
import pandas as pd

# %%
index = range(n_samples)
columns = ["feature {}".format(i) for i in range(n_features)] + ["labels"]

# %%
data = pd.DataFrame(np.c_[X,y], index, columns)

# %%
data.head()
# Out:
#    feature 0  feature 1  feature 2  feature 3  feature 4  feature 5  \
# 0   0.001466   0.007524   0.008064  -0.007273  -0.010479  -0.000671
# 1   0.019410   0.005230  -0.015379   0.019731  -0.004729  -0.000683
# 2  -0.007841   0.016874  -0.001004   0.007601   0.014292   0.003327
# 3   0.003410   0.004061  -0.002180  -0.010980  -0.021952   0.019059
# 4   0.019048   0.000765  -0.010767  -0.003173   0.002241   0.007586
#
#    feature 6  feature 7  feature 8  feature 9  ...  feature 11  feature 12  \
# 0   0.013578   0.007505   0.012376   0.004284  ...   -0.001129    0.004379
# 1  -0.000895  -0.000052   0.004301  -0.008073  ...   -0.006325    0.005668
# 2   0.005159   0.008993   0.005305  -0.004705  ...   -0.000195   -0.007552
# 3  -0.010808   0.019177  -0.003279   0.000875  ...   -0.009930   -0.003738
# 4   0.003493  -0.002060  -0.005076  -0.002364  ...   -0.015701    0.008247
#
#    feature 13  feature 14  feature 15  feature 16  feature 17  feature 18  \
# 0   -0.008238    0.002031   -0.007051    0.005700   -0.002221   -0.005104
# 1   -0.006890    0.000119   -0.004547    0.003893    0.015109   -0.015742
# 2   -0.004345   -0.008433   -0.004115    0.008892    0.011105    0.007210
# 3    0.004502   -0.002951   -0.001519    0.001428    0.010055   -0.013752
# 4    0.006875    0.008138   -0.000171   -0.017122    0.009431   -0.000344
#
#    feature 19    labels
# 0   -0.000688  3.423790
# 1   -0.006864 -1.155059
# 2    0.009380  3.278838
# 3   -0.015318  0.070120
# 4    0.007004 -1.269827
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
# feature 0     10000 non-null float64
# feature 1     10000 non-null float64
# feature 2     10000 non-null float64
# feature 3     10000 non-null float64
# feature 4     10000 non-null float64
# feature 5     10000 non-null float64
# feature 6     10000 non-null float64
# feature 7     10000 non-null float64
# feature 8     10000 non-null float64
# feature 9     10000 non-null float64
# feature 10    10000 non-null float64
# feature 11    10000 non-null float64
# feature 12    10000 non-null float64
# feature 13    10000 non-null float64
# feature 14    10000 non-null float64
# feature 15    10000 non-null float64
# feature 16    10000 non-null float64
# feature 17    10000 non-null float64
# feature 18    10000 non-null float64
# feature 19    10000 non-null float64
# labels        10000 non-null float64
# dtypes: float64(21)
# memory usage: 1.6 MB

# %%
data.describe()
# Out:
#           feature 0     feature 1     feature 2     feature 3     feature 4  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.000128     -0.000063      0.000035     -0.000042      0.000027
# std        0.009258      0.008695      0.009335      0.009026      0.008812
# min       -0.032088     -0.032202     -0.033285     -0.040977     -0.035062
# 25%       -0.006154     -0.005927     -0.006278     -0.006118     -0.005921
# 50%        0.000127      0.000002      0.000049     -0.000013      0.000060
# 75%        0.006392      0.005832      0.006428      0.006137      0.006021
# max        0.037056      0.032681      0.037010      0.034334      0.030858
#
#           feature 5     feature 6     feature 7     feature 8     feature 9  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -0.000189      0.000086     -0.000004      0.000028      0.000136
# std        0.008813      0.008904      0.008949      0.008619      0.009042
# min       -0.034509     -0.030908     -0.034581     -0.033291     -0.037501
# 25%       -0.006169     -0.005871     -0.006189     -0.005805     -0.005973
# 50%       -0.000080      0.000057      0.000063      0.000017      0.000147
# 75%        0.005699      0.006030      0.006190      0.005812      0.006229
# max        0.029488      0.031710      0.034966      0.037400      0.034729
#
#        ...    feature 11    feature 12    feature 13    feature 14  \
# count  ...  10000.000000  10000.000000  10000.000000  10000.000000
# mean   ...      0.000080     -0.000167     -0.000122      0.000028
# std    ...      0.009266      0.009216      0.009285      0.009036
# min    ...     -0.039066     -0.032492     -0.034104     -0.036355
# 25%    ...     -0.006181     -0.006391     -0.006349     -0.006082
# 50%    ...      0.000130     -0.000069     -0.000261     -0.000074
# 75%    ...      0.006392      0.005857      0.006180      0.006205
# max    ...      0.033522      0.034326      0.033795      0.035927
#
#          feature 15    feature 16    feature 17    feature 18    feature 19  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -0.000024     -0.000171     -0.000062     -0.000036     -0.000011
# std        0.008675      0.009021      0.009395      0.008530      0.008760
# min       -0.031524     -0.032660     -0.037258     -0.029881     -0.031370
# 25%       -0.005886     -0.006195     -0.006534     -0.005736     -0.005998
# 50%        0.000085     -0.000307      0.000026     -0.000117      0.000033
# 75%        0.005753      0.005872      0.006195      0.005678      0.005878
# max        0.031235      0.036260      0.032589      0.036312      0.031742
#
#              labels
# count  10000.000000
# mean       0.992317
# std        1.773907
# min       -5.839180
# 25%       -0.200834
# 50%        0.976966
# 75%        2.180386
# max        7.878111
#
# [8 rows x 21 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(
# feature 12   -0.017434    0.017569    0.006347 -0.001007
# feature 13   -0.022677    0.089161    0.023612  0.048127
# feature 14    0.056923    0.037705   -0.014329  0.029555
# feature 15   -0.030772   -0.039259   -0.009809  0.006147
# feature 16   -0.011983   -0.040476    0.016016  0.283558
# feature 17    1.000000    0.029248    0.014983 -0.004236
# feature 18    0.029248    1.000000   -0.028384  0.378801
# feature 19    0.014983   -0.028384    1.000000  0.037011
# labels       -0.004236    0.378801    0.037011  1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# ## Gradual data collection setting

# %%
batch_size = 1000
feature_limit = 5

# %%
def feature_selection():
    
    ''' random feature selection '''
    
    return np.random.choice(n_features,size=feature_limit,replace=False)

# %%
n_batches = int(n_samples/batch_size)
for batch in range(n_batches):
    selected_features = feature_selection()
    X_batch = data[["feature {}".format(i) for i in selected_features]][batch*batch_size:(batch+1)*batch_size].copy()
    y_batch = data["labels"][batch*batch_size:(batch+1)*batch_size].copy()

# %%
X_batch.head()
# Out:
#       feature 11     feature 4  feature 0  feature 19  feature 15
# 9000   -0.014036  3.559511e-03   0.011870   -0.006493    0.002338
# 9001   -0.004448 -1.404177e-02  -0.003083    0.023082   -0.018366
# 9002   -0.008488 -2.397100e-03   0.009351    0.001565   -0.000827
# 9003    0.014190 -2.798590e-07  -0.007805   -0.000641   -0.006208
# 9004   -0.007525  2.467719e-04  -0.000246    0.014820    0.002405

# %% [markdown]
# ## Discover, Visualize and Look for Correlations

# %% [markdown]
# Handling the first batch only

# %%
selected_features = feature_selection()
X_batch1 = data[["feature {}".format(i) for i in selected_features]][0:batch_size].copy()
y_batch1 = data[["labels"]][0:batch_size].copy()
X_batch2 = data[["feature {}".format(i) for i in selected_features]][100:200].copy()
y_batch2 = data[["labels"]][100:200].copy()
X_batch3 = data[["feature {}".format(i) for i in selected_features]][200:300].copy()
y_batch3 = data[["labels"]][200:300].copy()

# %%
data_b1 = pd.concat([X_batch1,y_batch1], axis=1)
data_b2 = pd.concat([X_batch2,y_batch2], axis=1)
data_b3 = pd.concat([X_batch3,y_batch3], axis=1)

# %%
data_b1.head()
# Out:
#    feature 14  feature 6  feature 7  feature 16  feature 2    labels
# 0    0.002031   0.013578   0.007505    0.005700   0.008064  3.423790
# 1    0.000119  -0.000895  -0.000052    0.003893  -0.015379 -1.155059
# 2   -0.008433   0.005159   0.008993    0.008892  -0.001004  3.278838
# 3   -0.002951  -0.010808   0.019177    0.001428  -0.002180  0.070120
# 4    0.008138   0.003493  -0.002060   -0.017122  -0.010767 -1.269827

# %%
corr_matrix = data_b1.corr()

# %%
corr_matrix["labels"].sort_values(ascending=False)
# Out:
# labels        1.000000
# feature 2     0.448826
# feature 16    0.309893
# feature 7     0.210592
# feature 6     0.058139
# feature 14    0.009316
# Name: labels, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = data_b1.columns
# attributes = ["feature {}".format(i) for i in range(n_features)] + ["labels"]
scatter_matrix(data_b1[attributes], figsize=(15,10))
plt.show()

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import mutual_info_regression

# %%
X.shape
# Out:
# (10000, 20)

# %%
X_new = SelectKBest(f_regression, k=5).fit_transform(X,y)

# %%
X_new.shape
# Out:
# (10000, 5)

# %%
X_new
# Out:
# array([[ 0.0080642 , -0.00727274,  0.01237644,  0.01051051, -0.00510435],
#        [-0.01537911,  0.0197314 ,  0.00430108, -0.01767977, -0.01574179],
#        [-0.00100369,  0.00760149,  0.00530472,  0.00263436,  0.00720961],
#        ...,
#        [-0.01238132, -0.01486742, -0.00455977,  0.0144736 ,  0.00900861],
#        [ 0.00104132, -0.00389541,  0.00722553,  0.00664344,  0.00471019],
#        [-0.01350862,  0.00549312,  0.01162435,  0.00971351,  0.02040964]])

# %%
print(X[0,:])
# Out:
# [ 0.00146571  0.00752446  0.0080642  -0.00727274 -0.01047892 -0.00067142
#   0.01357804  0.00750462  0.01237644  0.00428447  0.01051051 -0.00112858
#   0.00437878 -0.00823798  0.00203102 -0.00705051  0.00570033 -0.00222126
#  -0.00510435 -0.00068761]

# %% [markdown]
# ### Computing p-values

# %%
from scipy import stats
import statsmodels.api as sm

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 1.548e+05
# Date:                Sat, 13 Jun 2020   Prob (F-statistic):               0.00
# Time:                        16:09:17   Log-Likelihood:                 8782.2
# No. Observations:               10000   AIC:                        -1.752e+04
# Df Residuals:                    9979   BIC:                        -1.737e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9987      0.001    991.119      0.000       0.997       1.001
# x1            -0.0094      0.111     -0.085      0.933      -0.226       0.208
# x2             0.1050      0.118      0.890      0.374      -0.126       0.336
# x3            90.8816      0.109    832.423      0.000      90.668      91.096
# x4            63.6899      0.114    558.731      0.000      63.466      63.913
# x5             0.0398      0.117      0.341      0.733      -0.189       0.269
# x6            -0.1101      0.116     -0.948      0.343      -0.338       0.118
# x7            -0.0474      0.114     -0.415      0.678      -0.271       0.176
# x8            39.3078      0.113    347.102      0.000      39.086      39.530
# x9            88.9284      0.118    753.764      0.000      88.697      89.160
# x10           39.1121      0.113    346.676      0.000      38.891      39.333
# x11           65.1912      0.109    596.873      0.000      64.977      65.405
# x12           -0.2083      0.110     -1.893      0.058      -0.424       0.007
# x13            0.0094      0.110      0.085      0.932      -0.207       0.225
# x14           -0.0942      0.110     -0.853      0.394      -0.311       0.122
# x15            0.1098      0.113      0.973      0.331      -0.111       0.331
# x16           -0.0880      0.117     -0.750      0.453      -0.318       0.142
# x17           63.3315      0.113    562.233      0.000      63.111      63.552
# x18            0.0888      0.109      0.814      0.415      -0.125       0.302
# x19           73.0291      0.120    608.847      0.000      72.794      73.264
# x20            0.0287      0.117      0.247      0.805      -0.200       0.257
# ==============================================================================
# Omnibus:                        1.323   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.516   Jarque-Bera (JB):                1.291
# Skew:                          -0.015   Prob(JB):                        0.524
# Kurtosis:                       3.046   Cond. No.                         132.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
